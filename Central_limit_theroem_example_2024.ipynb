# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv("C:/Users/MANISHA/chapter9_assets/4_clt_solar_panels_coding/bill_survey.csv")

# %%
df.head()
# Out:
#      City   Bill
# 0  Mumbai  15400
# 1  Mumbai   6700
# 2  Mumbai  16300
# 3  Mumbai   2100
# 4  Mumbai   4600

# %%
df.shape
# Out:
# (10350, 2)

# %%
df.City.nunique()
# Out:
# 207

# %%
df.City.value_counts()
# Out:
# Mumbai          50
# Nizamabad       50
# Bijapur         50
# Rampur          50
# Shivamogga      50
#                 ..
# Kochi           50
# Bhavnagar       50
# Dehradun        50
# Durgapur        50
# Secunderabad    50
# Name: City, Length: 207, dtype: int64

# %%
sns.histplot(df.Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %% [markdown]
# ## Seeing distribution on city basis

# %%
sns.histplot(df[df.City=='Mumbai'].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sns.histplot(df[df.City=='Delhi'].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sns.histplot(df[df.City=='Bangalore'].Bill,kde=True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %% [markdown]
# ## Calculating sample mean

# %%
sample_means = []

for city,subdf in df.groupby("City"):
    print(city,subdf.Bill.mean())
# Out:
# Agartala 6276.0
# Agra 6084.0
# Ahmedabad 5990.0
# Ahmednagar 5588.0
# Aizawl 5680.0
# Ajmer 5448.0
# Akola 6426.0
# Aligarh 6340.0
# Allahabad 5714.0
# Alwar 5630.0
# Ambattur 4784.0
# Ambernath 6670.0
# Amravati 4738.0
# Amritsar 5544.0
# Anantapur 5718.0
# Arrah 6334.0
# Asansol 5414.0
# Aurangabad 6284.0
# Avadi 5130.0
# Bally 5962.0
# Bangalore 5582.0
# Baranagar 5702.0
# Barasat 5346.0
# Bardhaman 6356.0
# Bareilly 5944.0
# Bathinda 5976.0
# Begusarai 5872.0
# Belgaum 6412.0
# Bellary 6420.0
# Bhagalpur 6082.0
# Bharatpur 6298.0
# Bhatpara 4968.0
# Bhavnagar 6378.0
# Bhilai 6698.0
# Bhilwara 5856.0
# Bhiwandi 5426.0
# Bhopal 6438.0
# Bhubaneswar 6090.0
# Bihar Sharif 4978.0
# Bijapur 6426.0
# Bikaner 5364.0
# Bilaspur 5356.0
# Bokaro 5584.0
# Brahmapur 6390.0
# Bulandshahr 5202.0
# Chandigarh 6310.0
# Chandrapur 5506.0
# Chennai 6476.0
# Coimbatore 6300.0
# Cuttack 6620.0
# Darbhanga 6096.0
# Davanagere 4482.0
# Dehradun 6616.0
# Delhi 6298.0
# Dewas 5978.0
# Dhanbad 5332.0
# ...

# %%
sample_means = []

for city,subdf in df.groupby("City"):
    sample_means.append(subdf.Bill.mean())
    
len(sample_means)
# Out:
# 207

# %%
sns.histplot(sample_means,kde=True)
# Out:
# <Axes: ylabel='Count'>
